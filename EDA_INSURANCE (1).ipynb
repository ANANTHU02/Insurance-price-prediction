# %% [markdown]
# **MEDICAL INSURANCE COST PREDICTION**
#
# Hospital ABC, a leading healthcare provider, aims to optimize its resource allocation and improve patient care by understanding the factors influencing medical costs for its patients. To achieve this, Hospital ABC has collected a comprehensive dataset containing information about patients' demographics, lifestyle, health status, and medical expenses etc. The dataset includes attributes such as age, gender, BMI, smoking status, region, as well as additional information like occupation, exercise frequency, chronic conditions, and more.![Screenshot (323).png](data:image/png;base64,...![Alcohol.png](data:image/png;base64,...))

# %% [markdown]
# **PROBLEM STATEMENT**
#
#
# To predict medical costs for patients based on demographic factors, lifestyle-related information, health status, insurance plan type, family medical history, distance to the nearest hospital, and primary care physician visits.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/DATASET/medical data - Sheet1.csv')  #import dataset

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'BMI', 'Children', 'Smoker', 'Region', 'Occupation',
#        'Exercise_Frequency', 'Chronic_Conditions', 'Insurance_Plan_Type',
#        'Marital_Status', 'Distance_to_Nearest_Hospital', 'Income_Level',
#        'Family_Medical_History', 'Primary_Care_Physician_Visits',
#        'Mental_Health_Status', 'Prescription_Medication_Usage',
#        'Employment_Status', 'Education_Level', 'Dietary_Habits',
#        'Alcohol_Consumption', 'Sleep_Quality', 'Stress_Level',
#        'Medication_Adherence', 'Physical_Activity', 'Access_to_Healthcare',
#        'Social_Support', 'Environmental_Factors', 'Genetic_Predisposition',
#        'Health_Literacy_Level', 'Comorbidities', 'Access_to_Telemedicine',
#        'Emergency_Room_Visits', 'Healthcare_Utilization', 'Charges'],
#       dtype='object')

# %% [markdown]
# **Features of Dataset**
#
# **Demographic Information:**
#
# ● Age:The age of the patient in years.
#
# ● Sex: The gender of the patient, either 'M' (male) or 'F' (female).
#
# ● BMI (Body Mass Index): A numerical value representing the body mass index of the
# patient, which is calculated using their weight and height.
#
# ●Children: The number of children the patient has.
#
# ● Marital_Status: The marital status of the patient, either 'Married' or 'Single'.
#
# ● Income_Level: The income level of the patient, categorized as 'Low', 'Medium', or 'High'.
#
# ● Occupation: The occupation of the patient, which can be 'White Collar', 'Blue Collar',
# 'Professional', 'Student', 'Retired', or 'Self Employed'.
#
# ● Education_Level: The highest level of education attained by the patient, such as 'High
# School', "Bachelor's Degree", "Master's Degree", 'PhD', or missing (NaN).
#
# ● Employment_Status: The employment status of the patient, which can be 'Employed',
# 'Unemployed', 'Self Employed', or missing (NaN).
#
#
# **Lifestyle and Health-Related Information:**
#
# ● Exercise_Frequency: The frequency of exercise for the patient, such as 'Daily', '2
# times/week', '3 times/week', 'Once a week', or 'Rarely'.
#
# ● Chronic_Conditions: Any chronic conditions the patient may have, such as 'None',
# 'Diabetes', 'High Blood Pressure', 'Heart Disease', or 'Arthritis'.
#
# ● Smoker: Indicates whether the patient is a smoker or not, with values 'Yes' or 'No'.
#
# ● Alcohol_Consumption: Indicates the frequency of alcohol consumption by the patient,
# such as 'Never', 'Occasionally', 'Regularly', or missing (NaN).
#
# ● Dietary_Habits: Describes the patient's dietary habits, such as 'Vegetarian',
# 'Non-Vegetarian', 'Vegan', or missing (NaN).
#
# ● Sleep_Quality: Subjective assessment of the patient's sleep quality, categorized as 'Poor',
# 'Fair', 'Good', 'Excellent', or missing (NaN).
#
# ● Stress_Level: Measures the perceived stress level of the patient, categorized as 'Low',
# 'Moderate', 'High', or missing (NaN).
#
# ● Physical_Activity: Additional information on the patient's physical activity level, such as
# participation in sports or specific exercise routines, categorized as 'Low', 'Moderate',
# 'High', or missing (NaN).
#
# ● Mental_Health_Status: The mental health status of the patient, categorized as 'Poor', 'Fair',
# 'Good', or 'Excellent'.
#
# ● Prescription_Medication_Usage: Indicates whether the patient uses prescription
# medication or not, with values 'Yes' or 'No'.
#
# ● Medication_Adherence: Indicates the patient's adherence to prescribed medications, with
# values 'Yes', 'No', or missing (NaN).
#
# ● Genetic_Predisposition: Indicates whether the patient has a known genetic predisposition
# to certain health conditions, with values 'Yes', 'No', or missing (NaN).
#
# ● Comorbidities: Additional chronic conditions or comorbidities not captured in the "Chronic
# Conditions" feature, such as 'Asthma', 'Allergies', 'Cancer', 'Obesity', 'Hypertension', 'Other',
# or missing (NaN).
#
#
# **Healthcare and Access Information:**
#
# ● Insurance_Plan_Type: The type of insurance plan the patient has, which can be 'PPO',
# 'HMO', or 'HDHP'.
#
# ● Family_Medical_History: Indicates whether the patient has a family medical history or not,
# with values 'Yes' or 'No'.
#
# ● Primary_Care_Physician_Visits: The number of visits the patient makes to their primary
# care physician.
#
# ● Distance_to_Nearest_Hospital: The distance to the nearest hospital from the patient's
# residence.
#
# ● Access_to_Healthcare: Describes the ease of access to healthcare services for the
# patient, categorized as 'Easy', 'Moderate', 'Difficult', or missing (NaN).
#
# ● Access_to_Telemedicine: Indicates whether the patient has access to telemedicine
# services for remote consultations, with values 'Yes', 'No', or missing (NaN).
#
# ● Emergency_Room_Visits: The frequency of visits to the emergency room by the patient.
#
# ● Healthcare_Utilization: Measures the overall utilization of healthcare services by the
# patient, including hospital admissions, specialist consultations, etc.
#
# ● Environmental_Factors: Any environmental factors that may impact the patient's health or
# healthcare expenses, categorized as 'Low', 'Moderate', 'High', or missing (NaN).
#
# ● Social_Support: Measures the level of social support available to the patient, categorized
# as 'Low', 'Moderate', 'High', or missing (NaN).
#
# ● Health_Literacy_Level: Measures the patient's level of health literacy, categorized as
# 'Low', 'Moderate', 'High', or missing (NaN).
#
# **Outcome Variable:**
#
# Charges (Medical insurance charges incurred by the patient)

# %%
pd.set_option('display.max_columns', None)
df.head()  #First five rows of the dataset
# Out:
#    Age Sex       BMI  Children Smoker Region     Occupation  \
# 0   62   M  23.39610         4    Yes   East   White Collar
# 1   65   M  22.03668         4    Yes  North        Retired
# 2   71   M  23.03985         1     No  North        Retired
# 3   18   F  24.82284         0    Yes  North  Self Employed
# 4   21   M  23.44420         1     No  North   Professional
#
#   Exercise_Frequency Chronic_Conditions Insurance_Plan_Type Marital_Status  \
# 0             Rarely      Heart Disease                 HMO        Married
# 1       2 times/week      Heart Disease                HDHP         Single
# 2             Rarely                NaN                 HMO         Single
# 3              Daily          Arthritis                 PPO         Single
# 4              Daily          Arthritis                HDHP         Single
#
#    Distance_to_Nearest_Hospital Income_Level Family_Medical_History  \
# 0                      5.112872          Low                    Yes
# ...

# %%
df.tail() #Last five rows of the dataset.
# Out:
#      Age Sex       BMI  Children Smoker Region   Occupation  \
# 995   75   M  24.18366         3     No   West  Blue Collar
# 996   24   F  36.91005         0     No   East      Student
# 997   37   M  25.34770         4    Yes  North  Blue Collar
# 998   52   F  26.18630         1     No   West      Retired
# 999   68   M  31.11520         1    Yes   West  Blue Collar
#
#     Exercise_Frequency   Chronic_Conditions Insurance_Plan_Type  \
# 995              Daily                  NaN                 PPO
# 996       3 times/week            Arthritis                HDHP
# 997       3 times/week  High Blood Pressure                 HMO
# 998        Once a week  High Blood Pressure                 HMO
# 999             Rarely            Arthritis                HDHP
#
#     Marital_Status  Distance_to_Nearest_Hospital Income_Level  \
# 995         Single                      5.041508          Low
# 996        Married                     11.672830       Medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1000 non-null   int64
#  1   Sex                            1000 non-null   object
#  2   BMI                            984 non-null    float64
#  3   Children                       1000 non-null   int64
#  4   Smoker                         999 non-null    object
#  5   Region                         999 non-null    object
#  6   Occupation                     1000 non-null   object
#  7   Exercise_Frequency             1000 non-null   object
#  8   Chronic_Conditions             796 non-null    object
#  9   Insurance_Plan_Type            1000 non-null   object
#  10  Marital_Status                 1000 non-null   object
#  11  Distance_to_Nearest_Hospital   994 non-null    float64
# ...

# %% [markdown]
# The dataset shows various columns containing both numerical and categorical data.
#
#
#
# *   Total Entries: 1000 rows
# *   Columns: 35 columns

# %%
df.describe()
# Out:
#                Age         BMI     Children  Distance_to_Nearest_Hospital  \
# count  1000.000000  984.000000  1000.000000                    994.000000
# mean     48.167000   25.096119     1.918000                     10.623046
# std      18.009427    4.929889     1.428747                      5.449890
# min      18.000000    8.889366     0.000000                      1.000381
# 25%      33.000000   21.891128     1.000000                      5.893609
# 50%      48.000000   25.270985     2.000000                     10.953870
# 75%      64.000000   28.176527     3.000000                     15.288303
# max      79.000000   39.558080     4.000000                     19.996930
#
#        Primary_Care_Physician_Visits  Emergency_Room_Visits  \
# count                    1000.000000             993.000000
# mean                        4.964000               2.028197
# std                         2.599897               1.414645
# ...

# %% [markdown]
# The df.describe() output provides statistical summaries for the numerical columns in your dataset.
#
# Here's a breakdown of the key statistics:
#
#
# *   The dataset contains information on patients with ages ranging from 18 to 79 years.
# *   The average BMI is around 25, which falls within the normal weight range but can vary widely.
#
#
# *   Most patients have 1 to 3 children.
# *   The distance to the nearest hospital ranges from 1 to 20 miles, with an average of about 10.62 miles.
#
#
# *   Patients visit their primary care physician approximately 5 times on average.
# *   Emergency room visits and overall healthcare utilization show a moderate distribution across the dataset.
#
#
# *   Medical insurance charges vary significantly, with a mean charge of approximately $10,149.25.

# %%
df.isnull().sum()
#Showing the total number of null values in each columns
# Out:
# Age                                0
# Sex                                0
# BMI                               16
# Children                           0
# Smoker                             1
# Region                             1
# Occupation                         0
# Exercise_Frequency                 0
# Chronic_Conditions               204
# Insurance_Plan_Type                0
# Marital_Status                     0
# Distance_to_Nearest_Hospital       6
# Income_Level                       0
# Family_Medical_History             0
# Primary_Care_Physician_Visits      0
# Mental_Health_Status               0
# Prescription_Medication_Usage      0
# Employment_Status                252
# Education_Level                  198
# Dietary_Habits                   241
# Alcohol_Consumption              240
# Sleep_Quality                    214
# Stress_Level                     245
# Medication_Adherence             311
# Physical_Activity                254
# ...

# %% [markdown]
# It appears that your dataset contains several missing values across multiple columns.
#
# Handling Missing Values:
#
# Imputation:
#
# For numerical columns (BMI, Distance_to_Nearest_Hospital, Emergency_Room_Visits, Healthcare_Utilization), consider using median imputation to replace missing values.
#
# For categorical columns (Smoker, Region, Chronic_Conditions, Employment_Status, etc.), replace missing values with the mode (most frequent category) or treat missing values as a separate category.

# %%
import matplotlib.pyplot as plt
# Create a boxplot for the 'BMI' column
plt.figure(figsize=(3, 5))
df.boxplot(column='BMI')
plt.title('Boxplot of BMI')
plt.ylabel('BMI')
plt.show()


# Create a boxplot for the 'Distance_to_Nearest_Hospital ' column
plt.figure(figsize=(3, 5))
df.boxplot(column='Distance_to_Nearest_Hospital')
plt.title('Distance_to_Nearest_Hospital ')
plt.ylabel('Distance_to_Nearest_Hospital ')
plt.show()

# Create a boxplot for the 'Emergency_Room_Visits' column
plt.figure(figsize=(3, 5))
df.boxplot(column='Emergency_Room_Visits')
plt.title('Emergency_Room_Visits')
plt.ylabel('Emergency_Room_Visits')
plt.show()

# Create a boxplot for the 'Healthcare_Utilization' column
plt.figure(figsize=(3, 5))
df.boxplot(column='Healthcare_Utilization')
plt.title('Healthcare_Utilization')
plt.ylabel('Healthcare_Utilization')
plt.show()

# %% [markdown]
# FILL THE NULL VALUE COLUMNS OF BMI, Distance_to_Nearest_Hospital, Emergency_Room_Visits, Healthcare_Utilization with median values.

# %%
# Fill null values in the 'BMI' column with 25
df['BMI'].fillna(25, inplace=True)

# Fill null values in the 'Distance_to_Nearest_Hospital' column with 11
df['Distance_to_Nearest_Hospital'].fillna(11, inplace=True)

# Fill null values in the 'Emergency_Room_Visits' column with 2
df['Emergency_Room_Visits'].fillna(2, inplace=True)

# Fill null values in the 'Healthcare_Utilization' column with 10
df['Healthcare_Utilization'].fillna(10, inplace=True)

# %%
# Define the list of categorical columns
categorical_cols = ['Smoker', 'Region', 'Chronic_Conditions']

# Impute missing values in categorical columns with mode
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode().iloc[0])

# %% [markdown]
# Fill the categorical columns smoker, region, chronic conditions with the mode vaues.

# %%
df.isnull().sum()
# Out:
# Age                                0
# Sex                                0
# BMI                                0
# Children                           0
# Smoker                             0
# Region                             0
# Occupation                         0
# Exercise_Frequency                 0
# Chronic_Conditions                 0
# Insurance_Plan_Type                0
# Marital_Status                     0
# Distance_to_Nearest_Hospital       0
# Income_Level                       0
# Family_Medical_History             0
# Primary_Care_Physician_Visits      0
# Mental_Health_Status               0
# Prescription_Medication_Usage      0
# Employment_Status                252
# Education_Level                  198
# Dietary_Habits                   241
# Alcohol_Consumption              240
# Sleep_Quality                    214
# Stress_Level                     245
# Medication_Adherence             311
# Physical_Activity                254
# ...

# %%
selected_columns = ['Alcohol_Consumption', 'Sleep_Quality', 'Stress_Level', 'Employment_Status', 'Education_Level', 'Dietary_Habits', 'Medication_Adherence', 'Physical_Activity', 'Access_to_Healthcare', 'Social_Support', 'Environmental_Factors', 'Genetic_Predisposition', 'Health_Literacy_Level', 'Comorbidities', 'Access_to_Telemedicine']

# Print unique values for each selected column
for column in selected_columns:
    unique_values = df[column].unique()
    print("Unique values of the '{}' column:".format(column))
    print(unique_values)
    print(df[column].value_counts())
    print(df[column].isnull().sum())
    print()
# Out:
# Unique values of the 'Alcohol_Consumption' column:
# ['Regularly' nan 'Never' 'Occasionally']
# Alcohol_Consumption
# Never           267
# Regularly       255
# Occasionally    238
# Name: count, dtype: int64
# 240
#
# Unique values of the 'Sleep_Quality' column:
# ['Good' 'Fair' 'Poor' nan 'Excellent']
# Sleep_Quality
# Good         208
# Poor         204
# Excellent    191
# Fair         183
# Name: count, dtype: int64
# 214
#
# Unique values of the 'Stress_Level' column:
# [nan 'Low' 'Moderate' 'High']
# Stress_Level
# Low         263
# Moderate    247
# High        245
# Name: count, dtype: int64
# 245
#
# Unique values of the 'Employment_Status' column:
# [nan 'Employed' 'Unemployed' 'Self Employed']
# Employment_Status
# Self Employed    268
# Unemployed       242
# Employed         238
# Name: count, dtype: int64
# 252
#
# Unique values of the 'Education_Level' column:
# ["Master's Degree" 'High School' 'PhD' nan "Bachelor's Degree"]
# Education_Level
# ...

# %%
duplicate_rows = df.duplicated()
num_duplicates = duplicate_rows.sum()

# Print the number of duplicate rows
print("Total number of duplicate rows:", num_duplicates)
# Out:
# Total number of duplicate rows: 0

# %%
import seaborn as sns

education_order = ["Master's Degree", "Bachelor's Degree", 'PhD', 'High School']

# Plot the countplot
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Education_Level', hue='Employment_Status', order=education_order)
plt.title('Distribution of Education Levels by Employment Status')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Employment Status')
plt.tight_layout()
plt.show()

# %% [markdown]
# The daigram shows the relationship between education level end employment status. The daigram don't shows any specific relation between the education level and employment status.

# %% [markdown]
# **Count of Stress level by Employment status**

# %% [markdown]
# ![Screenshot (323).png](data:image/png;base64,...)

# %%
# Define the value to use for replacing missing values in 'Employment_Status'
replacement_value = 'Unknown'

# Replace null values in 'Employment_Status' with the specified value
df['Employment_Status'].fillna(replacement_value, inplace=True)

# Verify that missing values in 'Employment_Status' have been replaced
print(df['Employment_Status'].isnull().sum())  # Should print 0 if all missing values are replaced

# Optionally, display unique values in 'Employment_Status' after replacement
print(df['Employment_Status'].unique())
# Out:
# 0
# ['Unknown' 'Employed' 'Unemployed' 'Self Employed']

# %%
education_order = ["Master's Degree", "Bachelor's Degree", 'PhD', 'High School']

# Plot the countplot
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Education_Level', hue='Income_Level', order=education_order)
plt.title('Distribution of Education Levels by Income_Level')
plt.xlabel('Education Level')
#plt.ylabel('Income_Level')
plt.xticks(rotation=45)
plt.legend(title='Income_Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# The figure shows the relationship between education level and income level, it points that there is no specific relationship between the education level and the income level among the people

# %%
# Example: Replace missing values with 'Unknown' category
df['Education_Level'].fillna('Unknown', inplace=True)

# %%
Dietary_Habits_order = ['Non-Vegetarian', 'Vegetarian', 'Vegan']

# Plot the countplot
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Dietary_Habits', hue='Region', order=Dietary_Habits_order)
plt.title('Distribution of Dietary_Habits by Region')
plt.xlabel('Dietary_Habit')
#plt.ylabel('Region')
plt.xticks(rotation=45)
plt.legend(title='Region')
plt.tight_layout()
plt.show()

# %% [markdown]
# The figure shows the relationship between dietary habit and region, it shows that the people of south have high consumption of food in both non vegetarian vegetarian and vegan categories.

# %%
# Replace missing values with 'Unknown'
df['Dietary_Habits'].fillna('Unknown', inplace=True)

# %% [markdown]
# Count of smoker by alcohol consumaption

# %% [markdown]
# ![Alcohol.png](data:image/png;base64,...)

# %% [markdown]
# The figure shows the relationship between the count of smoker and alcohol consumption. It shows that the count of smokers is high in non alcoholic people.

# %%
# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Alcohol_Consumption'].fillna('Unknown', inplace=True)

# %%
# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Sleep_Quality'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Stress_Level'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Medication_Adherence'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Physical_Activity'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Access_to_Healthcare'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Social_Support'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Environmental_Factors'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Genetic_Predisposition'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Comorbidities'].fillna('Unknown', inplace=True)

# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Access_to_Telemedicine'].fillna('Unknown', inplace=True)


# Replace missing values with a specific value (e.g., 'None' or 'Not Reported')
df['Health_Literacy_Level'].fillna('Unknown', inplace=True)

# %% [markdown]
# Using a consistent placeholder value like 'Unknown' can be a valid approach to handle missing categorical data, especially when the missingness might carry some meaningful information (e.g., the absence of a reported value). This approach helps retain the information that the data was missing without introducing bias

# %%
df.isnull().sum()
# Out:
# Age                              0
# Sex                              0
# BMI                              0
# Children                         0
# Smoker                           0
# Region                           0
# Occupation                       0
# Exercise_Frequency               0
# Chronic_Conditions               0
# Insurance_Plan_Type              0
# Marital_Status                   0
# Distance_to_Nearest_Hospital     0
# Income_Level                     0
# Family_Medical_History           0
# Primary_Care_Physician_Visits    0
# Mental_Health_Status             0
# Prescription_Medication_Usage    0
# Employment_Status                0
# Education_Level                  0
# Dietary_Habits                   0
# Alcohol_Consumption              0
# Sleep_Quality                    0
# Stress_Level                     0
# Medication_Adherence             0
# Physical_Activity                0
# Access_to_Healthcare             0
# Social_Support                   0
# ...

# %%
#Gender column

plt.figure(figsize=(6,6))
sns.countplot(x='Sex', data=df)
plt.title('Sex distribution')
plt.show()

# %% [markdown]
# The figure shows that the dataset contains more number of female data.

# %%
df['Sex'].value_counts()
# Out:
# Sex
# F    514
# M    486
# Name: count, dtype: int64

# %%
#distribution of age value
sns.set()
plt.figure(figsize=(5,5))
sns.distplot(df['Age'])
plt.title('Age Distribution')
plt.show()
# Out:
# <ipython-input-26-e2520e02f3d2>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %% [markdown]
# The figure shows the density of age distribution the figure shows that the age ranges between the range of 20 to 80. The density of the age is high at 20 to 23.

# %%
#distribution of BMI
sns.set()
plt.figure(figsize=(5,5))
sns.distplot(df['BMI'])
plt.title('BMI Distribution')
plt.show()
# Out:
# <ipython-input-27-46f44e65167e>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BMI'])

# %% [markdown]
# The figure shows the density of BMI it shows that the BMI density is high in the range of 25 t, 26 and 27.

# %%
#children column

plt.figure(figsize=(5,5))
sns.countplot(x='Children', data=df)
plt.title('Children')
plt.show()

# %% [markdown]
# The figure shows the count of children, it shows that the count of one child or no children are high.

# %%
df['Children'].value_counts()
# Out:
# Children
# 1    218
# 0    216
# 4    198
# 2    196
# 3    172
# Name: count, dtype: int64

# %%
#Smoker column

plt.figure(figsize=(5,5))
sns.countplot(x='Smoker', data=df)
plt.title('Smoker')
plt.show()

# %% [markdown]
# The figure shows the count of smokers and non smokers, it shows that the count of smokers is high as compared to non smoking people.

# %%
df['Smoker'].value_counts()
# Out:
# Smoker
# Yes    511
# No     489
# Name: count, dtype: int64

# %%
#Region column

plt.figure(figsize=(5,5))
sns.countplot(x='Region', data=df)
plt.title('Region')
plt.show()

# %% [markdown]
# The figure shows that the south region contains more number of people.

# %%
df['Region'].value_counts()
# Out:
# Region
# South    275
# North    264
# West     244
# East     217
# Name: count, dtype: int64

# %%
#distribution of insurance charges
sns.set()
plt.figure(figsize=(5,5))
sns.distplot(df['Charges'])
plt.title('Charges Distribution')
plt.show()
# Out:
# <ipython-input-34-caabe297815c>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Charges'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1000 non-null   int64
#  1   Sex                            1000 non-null   object
#  2   BMI                            1000 non-null   float64
#  3   Children                       1000 non-null   int64
#  4   Smoker                         1000 non-null   object
#  5   Region                         1000 non-null   object
#  6   Occupation                     1000 non-null   object
#  7   Exercise_Frequency             1000 non-null   object
#  8   Chronic_Conditions             1000 non-null   object
#  9   Insurance_Plan_Type            1000 non-null   object
#  10  Marital_Status                 1000 non-null   object
#  11  Distance_to_Nearest_Hospital   1000 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Sex'] = le.fit_transform(df['Sex'])
df['Smoker'] = le.fit_transform(df['Smoker'])
df['Region'] = le.fit_transform(df['Region'])
df['Occupation'] = le.fit_transform(df['Occupation'])
df['Exercise_Frequency'] = le.fit_transform(df['Exercise_Frequency'])
df['Chronic_Conditions'] = le.fit_transform(df['Chronic_Conditions'])
df['Insurance_Plan_Type'] = le.fit_transform(df['Insurance_Plan_Type'])
df['Marital_Status'] = le.fit_transform(df['Marital_Status'])
df['Income_Level'] = le.fit_transform(df['Income_Level'])
df['Family_Medical_History'] = le.fit_transform(df['Family_Medical_History'])
df['Mental_Health_Status'] = le.fit_transform(df['Mental_Health_Status'])
df['Prescription_Medication_Usage'] = le.fit_transform(df['Prescription_Medication_Usage'])
df['Employment_Status'] = le.fit_transform(df['Employment_Status'])
df['Education_Level'] = le.fit_transform(df['Education_Level'])
df['Dietary_Habits'] = le.fit_transform(df['Dietary_Habits'])
df['Alcohol_Consumption'] = le.fit_transform(df['Alcohol_Consumption'])
df['Education_Level'] = le.fit_transform(df['Education_Level'])
df['Sleep_Quality'] = le.fit_transform(df['Sleep_Quality'])
df['Stress_Level'] = le.fit_transform(df['Stress_Level'])
df['Medication_Adherence'] = le.fit_transform(df['Medication_Adherence'])
df['Physical_Activity'] = le.fit_transform(df['Physical_Activity'])
df['Access_to_Healthcare'] = le.fit_transform(df['Access_to_Healthcare'])
df['Social_Support'] = le.fit_transform(df['Social_Support'])
df['Environmental_Factors'] = le.fit_transform(df['Environmental_Factors'])
df['Genetic_Predisposition'] = le.fit_transform(df['Genetic_Predisposition'])
df['Health_Literacy_Level'] = le.fit_transform(df['Health_Literacy_Level'])
df['Comorbidities'] = le.fit_transform(df['Comorbidities'])
df['Access_to_Telemedicine'] = le.fit_transform(df['Access_to_Telemedicine'])

# %% [markdown]
# Here we used LabelEncoder from scikit-learn to transform multiple categorical columns into numerical representations within your DataFrame df. This transformation is often necessary for preparing categorical data to be used as input in machine learning models, which typically require numerical data.
#
# LabelEncoder Usage: LabelEncoder is used to transform categorical data (text-based) into numerical labels (integer values). Each unique category in a column is assigned a unique integer label.
#
# Fit and Transform: You use le.fit_transform() for each categorical column to fit the encoder to the column's unique categories and transform the column values into encoded numerical labels.
#
# Column Overwriting: The original categorical columns in df are overwritten with the transformed numerical labels.

# %%
df.head()
# Out:
#    Age  Sex       BMI  Children  Smoker  Region  Occupation  \
# 0   62    1  23.39610         4       1       0           5
# 1   65    1  22.03668         4       1       1           2
# 2   71    1  23.03985         1       0       1           2
# 3   18    0  24.82284         0       1       1           3
# 4   21    1  23.44420         1       0       1           1
#
#    Exercise_Frequency  Chronic_Conditions  Insurance_Plan_Type  \
# 0                   4                   2                    1
# 1                   0                   2                    0
# 2                   4                   2                    1
# 3                   2                   0                    2
# 4                   2                   0                    0
#
#    Marital_Status  Distance_to_Nearest_Hospital  Income_Level  \
# 0               0                      5.112872             1
# 1               1                     19.006750             0
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
sns.heatmap(data = df.corr(), annot = True, fmt = '.2g', linewidth = 1)
plt.show()

# %%
corrs = df.corr()['Charges']
columns = corrs[corrs > .001].index
corrs = corrs.filter(columns)
corrs.sort_values(ascending = False)
# Out:
# Charges                          1.000000
# Family_Medical_History           0.096577
# BMI                              0.059949
# Medication_Adherence             0.053303
# Alcohol_Consumption              0.048376
# Health_Literacy_Level            0.047006
# Occupation                       0.038090
# Insurance_Plan_Type              0.030828
# Physical_Activity                0.029141
# Employment_Status                0.028775
# Prescription_Medication_Usage    0.026795
# Access_to_Healthcare             0.024319
# Chronic_Conditions               0.020400
# Social_Support                   0.019655
# Mental_Health_Status             0.018023
# Genetic_Predisposition           0.011887
# Exercise_Frequency               0.011819
# Primary_Care_Physician_Visits    0.008705
# Smoker                           0.008253
# Region                           0.001577
# Name: Charges, dtype: float64

# %%
feat = ['Family_Medical_History', 'BMI', 'Medication_Adherence', 'Alcohol_Consumption', 'Health_Literacy_Level',
          'Physical_Activity', 'Chronic_Conditions', 'Mental_Health_Status', 'Genetic_Predisposition',
         'Exercise_Frequency', 'Smoker','Sleep_Quality', 'Stress_Level'  ]

# %%
# Create a new DataFrame with selected features and target variable
df_selected = df[feat + ['Charges']]

# %%
df_selected
# Out:
#      Family_Medical_History       BMI  Medication_Adherence  \
# 0                         1  23.39610                     0
# 1                         0  22.03668                     0
# 2                         1  23.03985                     0
# 3                         1  24.82284                     0
# 4                         0  23.44420                     0
# ..                      ...       ...                   ...
# 995                       0  24.18366                     2
# 996                       1  36.91005                     2
# 997                       0  25.34770                     1
# 998                       0  26.18630                     0
# 999                       1  31.11520                     2
#
#      Alcohol_Consumption  Health_Literacy_Level  Physical_Activity  \
# 0                      2                      3                  1
# 1                      3                      2                  3
# ...

# %%
df_selected.shape
# Out:
# (1000, 14)

# %%
x = df_selected[feat]
y = df_selected['Charges']

# %%
x
# Out:
#      Family_Medical_History       BMI  Medication_Adherence  \
# 0                         1  23.39610                     0
# 1                         0  22.03668                     0
# 2                         1  23.03985                     0
# 3                         1  24.82284                     0
# 4                         0  23.44420                     0
# ..                      ...       ...                   ...
# 995                       0  24.18366                     2
# 996                       1  36.91005                     2
# 997                       0  25.34770                     1
# 998                       0  26.18630                     0
# 999                       1  31.11520                     2
#
#      Alcohol_Consumption  Health_Literacy_Level  Physical_Activity  \
# 0                      2                      3                  1
# 1                      3                      2                  3
# ...

# %%
x.shape
# Out:
# (1000, 13)

# %%
y
# Out:
# 0       7604.947
# 1       7067.338
# 2       4478.128
# 3      12944.880
# 4       8275.411
#          ...
# 995     7344.957
# 996    13072.180
# 997    10463.350
# 998     7296.749
# 999     7710.789
# Name: Charges, Length: 1000, dtype: float64

# %%
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=5)

# %%
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (700, 13) (700,) (300, 13) (300,)

# %% [markdown]
# **MODEL TRAINING**

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **MODEL EVALUATION**

# %%
#make prediction on the test data
y_pred = model.predict(x_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Squared Error (MSE): ", mse)
print("R squared value (on Testing Data): ", r2)
# Out:
# Mean Squared Error (MSE):  8955347.171790997
# R squared value (on Testing Data):  -0.024361535949002366

# %% [markdown]
# Mean Squared Error (MSE): 8955347.171790997
# This indicates that, on average, the squared difference between the predicted values and the true values (testing data) is approximately 8955347.171790997. Lower values of MSE are desirable, suggesting a better fit of the model to the data.
#
# R-squared (R^2) is a statistical measure that represents the proportion of variance in the dependent variable (target) that is predictable from the independent variables (features) in the model.
#
# R^2 value ranges from -∞ to 1. A value closer to 1 indicates a better fit of the model to the data, where the model explains a larger proportion of the variance in the target variable.
#
# R^2 value of 0 indicates that the model does not explain any variability in the target variable beyond the mean.
#
# R^2 value less than 0 suggests that the model performs worse than a model that simply predicts the mean of the target variable.

# %% [markdown]
# Building a Predictive System

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([10090.56410545,  9945.0225258 , 10229.88335506, 11045.2355639 ,
#        10561.7547699 , 10442.75961041,  9761.60943965, 10641.41712419,
#        10300.99412747, 10184.15924422,  9332.47816882, 10280.97400459,
#         9823.15027451, 10337.59660553,  8970.29340579,  8576.76212934,
#        10378.17388404,  9213.02247466,  9459.92251031,  9659.41259639,
#         9229.42514143, 10437.7392013 ,  9656.76545025,  9849.45071111,
#        10328.69682559, 10398.82484085, 10102.49904522, 10030.08529762,
#        10401.58289742, 10200.00253912,  9614.051007  , 10081.00441109,
#        10914.18540056, 10710.47908368,  9846.73778028, 10173.94142362,
#        10347.67295769,  9562.39934957,  9316.20795364, 10359.5888366 ,
#        10253.03681779, 10729.44006237, 10028.7927155 ,  9428.42446334,
#         9727.74197188,  8910.19132223,  9471.00929884,  8969.13522366,
#        10190.59646337,  9817.72071602,  9213.58583745, 10718.7661499 ,
# ...

# %%
import numpy as np

input_data = (1,	23.39610,	0,	2,	3,	5,	1,	1,	3,	0,	1,	2,	0)

#changing input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = model.predict(input_data_reshaped)
print(prediction)

print('The insurance cost: ', prediction[0])
# Out:
# [11411.20691412]
# The insurance cost:  11411.206914116985
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# DECISION TREE

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import tree
import matplotlib.pyplot as plt

# %%
# Create a Decision Tree Regressor model
tree_model = DecisionTreeRegressor(random_state=0)

# Train the model using the training data
tree_model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# Make predictions on the test data
y_pred = tree_model.predict(x_test)

# Calculate Mean Squared Error (MSE) and R-squared (R^2) value
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE): ", mse)
print("R-squared (R^2) value (on Testing Data): ", r2)
# Out:
# Mean Squared Error (MSE):  17765686.275553722
# R-squared (R^2) value (on Testing Data):  -1.0321362568431582

# %% [markdown]
# Pre-pruning using GridSearchCV in decision trees involves tuning hyperparameters ('max_depth', 'max_features', etc.) to control the complexity of the tree and prevent overfitting. This approach optimizes model performance by finding the best set of hyperparameters based on a specified evaluation metric. Adjusting these hyperparameters effectively can lead to better decision tree models with improved generalization capabilities.

# %%
#pre-pruning

from sklearn.model_selection import GridSearchCV

parameter = {
    'criterion': ['mse', 'friedman_mse', 'mae'],  # Use appropriate criteria for regression
    'max_depth': [1, 2, 3, 4, 5],
    'max_features': ['auto', 'sqrt', 'log2', None]
}

# Define the decision tree model for regression
model_tree = DecisionTreeRegressor(random_state=0)

# Create GridSearchCV instance with the decision tree model and parameter grid
cv = GridSearchCV(model_tree, parameter, scoring='r2')  # Use appropriate scoring metric for regression

# Fit the GridSearchCV to the training data
cv.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# ...

# %%
# Print the best parameters and best score found by GridSearchCV
print("Best Parameters:", cv.best_params_)
print("Best Score (R^2):", cv.best_score_)

# Optionally, evaluate the model performance on the test set
test_score = cv.score(x_test, y_test)
print("Test Set Score (R^2):", test_score)

best_model=cv.best_estimator_
best_model
# Out:
# Best Parameters: {'criterion': 'friedman_mse', 'max_depth': 3, 'max_features': 'sqrt'}
# Best Score (R^2): 0.011936159191139661
# Test Set Score (R^2): -0.03319822758414093
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=3,
#                       max_features='sqrt', random_state=0)

# %%
model = DecisionTreeRegressor(criterion= 'friedman_mse', max_depth = 3, max_features = 'sqrt')  #model obj creation
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=3,
#                       max_features='sqrt')

# %%
plt.figure(figsize=(15, 10))
plot_tree(best_model, feature_names=None, class_names=None, filled=True, rounded=True)
# Out:
# [Text(0.5, 0.875, 'x[5] <= 2.5\nfriedman_mse = 9147771.967\nsamples = 700\nvalue = 10119.56'),
#  Text(0.25, 0.625, 'x[11] <= 1.5\nfriedman_mse = 9041946.068\nsamples = 511\nvalue = 9995.681'),
#  Text(0.125, 0.375, 'x[12] <= 1.5\nfriedman_mse = 9101394.61\nsamples = 189\nvalue = 10179.048'),
#  Text(0.0625, 0.125, 'friedman_mse = 7948829.167\nsamples = 107\nvalue = 9977.05'),
#  Text(0.1875, 0.125, 'friedman_mse = 10482631.991\nsamples = 82\nvalue = 10442.632'),
#  Text(0.375, 0.375, 'x[8] <= 1.5\nfriedman_mse = 8975732.965\nsamples = 322\nvalue = 9888.053'),
#  Text(0.3125, 0.125, 'friedman_mse = 8243864.234\nsamples = 209\nvalue = 9561.593'),
#  Text(0.4375, 0.125, 'friedman_mse = 9767665.016\nsamples = 113\nvalue = 10491.86'),
#  Text(0.75, 0.625, 'x[4] <= 2.5\nfriedman_mse = 9280223.216\nsamples = 189\nvalue = 10454.493'),
#  Text(0.625, 0.375, 'x[8] <= 0.5\nfriedman_mse = 9276670.864\nsamples = 143\nvalue = 10257.562'),
# ...

# %% [markdown]
# RANDOM FOREST

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Initialize Random Forest Regressor with default hyperparameters
forest_model = RandomForestRegressor(random_state=0)

# Train the Random Forest model using the training data
forest_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
# Make predictions on the test data
y_pred = forest_model.predict(x_test)

# Calculate Mean Squared Error (MSE) and R-squared (R^2) value
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE) with Random Forest:", mse)
print("R-squared (R^2) value with Random Forest:", r2)
# Out:
# Mean Squared Error (MSE) with Random Forest: 9011760.282425031
# R-squared (R^2) value with Random Forest: -0.03081437574942547

# %% [markdown]
# GRADIENT BOOSTING MACHINE (GBM)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Initialize Gradient Boosting Regressor with default hyperparameters
gbm_model = GradientBoostingRegressor(random_state=0)

# Train the Gradient Boosting model using the training data
gbm_model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
# Make predictions on the test data
y_pred = gbm_model.predict(x_test)

# Calculate Mean Squared Error (MSE) and R-squared (R^2) value
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE) with Gradient Boosting:", mse)
print("R-squared (R^2) value with Gradient Boosting:", r2)
# Out:
# Mean Squared Error (MSE) with Gradient Boosting: 9110497.618669877
# R-squared (R^2) value with Gradient Boosting: -0.04210849170842246

# %% [markdown]
# SUPPORT VECTOR MACHINE(SVM)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Standardize the features (optional but recommended for SVM)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
# Initialize SVR model with default hyperparameters
svm_model = SVR(kernel='rbf')  # 'rbf' kernel is commonly used for non-linear relationships

# Train the SVR model using the scaled training data
svm_model.fit(x_train_scaled, y_train)
# Out:
# SVR()

# %%
# Make predictions on the scaled test data
y_pred = svm_model.predict(x_test_scaled)

# Calculate Mean Squared Error (MSE) and R-squared (R^2) value
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE) with SVM (SVR):", mse)
print("R-squared (R^2) value with SVM (SVR):", r2)
# Out:
# Mean Squared Error (MSE) with SVM (SVR): 8741886.506482255
# R-squared (R^2) value with SVM (SVR): 5.5261165143427604e-05

# %% [markdown]
# K-NEAREST NEIGHBORS(KNN)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Initialize KNN Regressor with a specified number of neighbors (e.g., k=5)
knn_model = KNeighborsRegressor(n_neighbors=5)  # You can adjust the number of neighbors (k) as needed

# Train the KNN model using the scaled training data
knn_model.fit(x_train_scaled, y_train)
# Out:
# KNeighborsRegressor()

# %%
# Make predictions on the scaled test data
y_pred = knn_model.predict(x_test_scaled)

# Calculate Mean Squared Error (MSE) and R-squared (R^2) value
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE) with KNN:", mse)
print("R-squared (R^2) value with KNN:", r2)
# Out:
# Mean Squared Error (MSE) with KNN: 10420274.920453569
# R-squared (R^2) value with KNN: -0.1919279752938876

# %% [markdown]
# **ANN**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
x_c = x.copy()
y_c = y.copy()

# %%
x_c
# Out:
#      Family_Medical_History       BMI  Medication_Adherence  \
# 0                         1  23.39610                     0
# 1                         0  22.03668                     0
# 2                         1  23.03985                     0
# 3                         1  24.82284                     0
# 4                         0  23.44420                     0
# ..                      ...       ...                   ...
# 995                       0  24.18366                     2
# 996                       1  36.91005                     2
# 997                       0  25.34770                     1
# 998                       0  26.18630                     0
# 999                       1  31.11520                     2
#
#      Alcohol_Consumption  Health_Literacy_Level  Physical_Activity  \
# 0                      2                      3                  1
# 1                      3                      2                  3
# ...

# %%
y_c
# Out:
# 0       7604.947
# 1       7067.338
# 2       4478.128
# 3      12944.880
# 4       8275.411
#          ...
# 995     7344.957
# 996    13072.180
# 997    10463.350
# 998     7296.749
# 999     7710.789
# Name: Charges, Length: 1000, dtype: float64

# %%
#split the data into training and testing sets
xc_train, xc_test, yc_train, yc_test = train_test_split(x_c, y_c, test_size=0.2, random_state=42)

# %%
xc_train.shape
# Out:
# (800, 13)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(13,)))
model.add(Dropout(0.2))  # Add dropout for regularization
model.add(Dense(32, activation='relu'))
model.add(Dense(1))  # Output layer for regression

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
history = model.fit(xc_train, yc_train, batch_size=32, epochs=1000, validation_split=0.2)
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 0s 9ms/step - loss: 9465900.0000 - val_loss: 8119017.0000
# Epoch 2/1000
# 20/20 [==============================] - 0s 3ms/step - loss: 9544227.0000 - val_loss: 8116017.0000
# Epoch 3/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 9592021.0000 - val_loss: 8108937.5000
# Epoch 4/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 10043237.0000 - val_loss: 8111361.5000
# Epoch 5/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 9710696.0000 - val_loss: 8138190.5000
# Epoch 6/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 9958739.0000 - val_loss: 8111075.0000
# Epoch 7/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 9650473.0000 - val_loss: 8112364.0000
# Epoch 8/1000
# 20/20 [==============================] - 0s 4ms/step - loss: 9722662.0000 - val_loss: 8113523.0000
# Epoch 9/1000
# ...

# %%
ypred = model.predict(xc_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
ypred
# Out:
# array([[ 9154.248 ],
#        [10209.843 ],
#        [10328.604 ],
#        [10825.804 ],
#        [10038.396 ],
#        [ 9274.013 ],
#        [ 9145.946 ],
#        [ 9847.319 ],
#        [10648.089 ],
#        [ 9337.283 ],
#        [ 9793.634 ],
#        [10067.314 ],
#        [10623.76  ],
#        [10124.172 ],
#        [ 9422.809 ],
#        [10496.122 ],
#        [ 9020.713 ],
#        [10560.559 ],
#        [ 9536.336 ],
#        [ 9399.584 ],
#        [ 9669.857 ],
#        [ 9909.051 ],
#        [ 9099.095 ],
#        [10033.64  ],
#        [10349.289 ],
#        [10540.133 ],
#        [ 9886.31  ],
#        [11094.158 ],
#        [10497.868 ],
#        [10325.891 ],
#        [10980.127 ],
#        [ 9683.223 ],
#        [ 9259.087 ],
#        [ 9836.211 ],
#        [ 9929.097 ],
#        [10446.106 ],
#        [10571.649 ],
#        [ 9955.012 ],
#        [ 9033.291 ],
#        [10400.904 ],
#        [10369.405 ],
#        [ 9221.918 ],
#        [10242.787 ],
# ...

# %%
yc_test.shape
# Out:
# (200,)

# %%
ypred.shape
# Out:
# (200, 1)

# %%
import numpy as np

# Reshape ypred to match the shape of yc_test
ypred_reshaped = ypred.reshape(-1)  # or ypred.flatten()

# Now ypred_reshaped should have the shape (200,)
print(ypred_reshaped.shape)
# Out:
# (200,)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assuming yc_test and ypred_reshaped are now both 1-dimensional arrays of the same shape (200,)
mae = mean_absolute_error(yc_test, ypred_reshaped)
mse = mean_squared_error(yc_test, ypred_reshaped)
r2 = r2_score(yc_test, ypred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R2 Score:", r2)
# Out:
# Mean Absolute Error: 2539.180973359375
# Mean Squared Error: 9893060.287200926
# R2 Score: 0.0021331131638183676

# %% [markdown]
# ANN Scaled

# %%
x_train_scaled.shape
# Out:
# (700, 13)

# %%
df.head()
# Out:
#    Age  Sex       BMI  Children  Smoker  Region  Occupation  \
# 0   62    1  23.39610         4       1       0           5
# 1   65    1  22.03668         4       1       1           2
# 2   71    1  23.03985         1       0       1           2
# 3   18    0  24.82284         0       1       1           3
# 4   21    1  23.44420         1       0       1           1
#
#    Exercise_Frequency  Chronic_Conditions  Insurance_Plan_Type  \
# 0                   4                   2                    1
# 1                   0                   2                    0
# 2                   4                   2                    1
# 3                   2                   0                    2
# 4                   2                   0                    0
#
#    Marital_Status  Distance_to_Nearest_Hospital  Income_Level  \
# 0               0                      5.112872             1
# 1               1                     19.006750             0
# ...

# %%
df.shape
# Out:
# (1000, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1000 non-null   int64
#  1   Sex                            1000 non-null   int64
#  2   BMI                            1000 non-null   float64
#  3   Children                       1000 non-null   int64
#  4   Smoker                         1000 non-null   int64
#  5   Region                         1000 non-null   int64
#  6   Occupation                     1000 non-null   int64
#  7   Exercise_Frequency             1000 non-null   int64
#  8   Chronic_Conditions             1000 non-null   int64
#  9   Insurance_Plan_Type            1000 non-null   int64
#  10  Marital_Status                 1000 non-null   int64
#  11  Distance_to_Nearest_Hospital   1000 non-null   float64
# ...

# %%
x1 = df.drop(columns = 'Charges')
y1 = df['Charges']

# %%
x1.head()
# Out:
#    Age  Sex       BMI  Children  Smoker  Region  Occupation  \
# 0   62    1  23.39610         4       1       0           5
# 1   65    1  22.03668         4       1       1           2
# 2   71    1  23.03985         1       0       1           2
# 3   18    0  24.82284         0       1       1           3
# 4   21    1  23.44420         1       0       1           1
#
#    Exercise_Frequency  Chronic_Conditions  Insurance_Plan_Type  \
# 0                   4                   2                    1
# 1                   0                   2                    0
# 2                   4                   2                    1
# 3                   2                   0                    2
# 4                   2                   0                    0
#
#    Marital_Status  Distance_to_Nearest_Hospital  Income_Level  \
# 0               0                      5.112872             1
# 1               1                     19.006750             0
# ...

# %%
y1.shape
# Out:
# (1000,)

# %%
#split the data into training and testing sets
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, random_state=42)

# %%
# Standardize the features (optional but recommended for SVM)
scaler = StandardScaler()
x1_train_scaled = scaler.fit_transform(x1_train)
x1_test_scaled = scaler.transform(x1_test)

# %%
x1_train_scaled.shape
# Out:
# (800, 34)

# %%
x1_test_scaled.shape
# Out:
# (200, 34)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
model2 = Sequential()
model2.add(Dense(34, activation='relu', input_shape=(34,)))
model2.add(Dropout(0.2))  # Add dropout for regularization
model2.add(Dense(32, activation='relu'))
model2.add(Dense(1))  # Output layer for regression

# %%
model2.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
history_scaled = model2.fit(x1_train, y1_train, batch_size=32, epochs=500, validation_split=0.2)
# Out:
# Epoch 1/500
# 20/20 [==============================] - 3s 42ms/step - loss: 111278016.0000 - val_loss: 112541616.0000
# Epoch 2/500
# 20/20 [==============================] - 0s 13ms/step - loss: 110793456.0000 - val_loss: 111868848.0000
# Epoch 3/500
# 20/20 [==============================] - 0s 18ms/step - loss: 109915608.0000 - val_loss: 110557904.0000
# Epoch 4/500
# 20/20 [==============================] - 0s 12ms/step - loss: 108182416.0000 - val_loss: 107946024.0000
# Epoch 5/500
# 20/20 [==============================] - 0s 13ms/step - loss: 104983024.0000 - val_loss: 103513000.0000
# Epoch 6/500
# 20/20 [==============================] - 0s 18ms/step - loss: 99781232.0000 - val_loss: 96667896.0000
# Epoch 7/500
# 20/20 [==============================] - 0s 12ms/step - loss: 92218928.0000 - val_loss: 87107512.0000
# Epoch 8/500
# 20/20 [==============================] - 0s 18ms/step - loss: 82037928.0000 - val_loss: 75067680.0000
# Epoch 9/500
# ...

# %%
y1_pred = model2.predict(x1_test)
# Out:
# 7/7 [==============================] - 0s 11ms/step

# %%
y1_pred
# Out:
# array([[ 9678.967 ],
#        [11441.191 ],
#        [12648.999 ],
#        [11889.74  ],
#        [ 9102.368 ],
#        [ 8528.312 ],
#        [ 8679.063 ],
#        [ 8758.913 ],
#        [11109.714 ],
#        [ 7986.954 ],
#        [ 9059.196 ],
#        [10014.554 ],
#        [10337.358 ],
#        [10486.895 ],
#        [ 9434.437 ],
#        [11440.498 ],
#        [ 8077.7676],
#        [10998.212 ],
#        [ 8292.747 ],
#        [ 9317.494 ],
#        [ 8812.61  ],
#        [10857.448 ],
#        [ 7169.9575],
#        [ 9756.767 ],
#        [10295.091 ],
#        [10723.317 ],
#        [ 9384.685 ],
#        [12517.82  ],
#        [ 9459.079 ],
#        [12007.44  ],
#        [11172.886 ],
#        [ 9383.489 ],
#        [ 8722.173 ],
#        [ 9598.339 ],
#        [10749.7   ],
#        [10550.812 ],
#        [10898.57  ],
#        [ 9407.733 ],
#        [ 9631.559 ],
#        [11054.519 ],
#        [ 9631.376 ],
#        [ 7550.5566],
#        [ 9455.517 ],
# ...

# %%
list1
